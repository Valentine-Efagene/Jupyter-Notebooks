# %%
from spatialmath import SE3

T = SE3(0.7, 0.2, 0.1) * SE3.OA([0, 1, 0], [0, 0, -1])
sol = robot.ikine_LM(T)         # solve IK
print(sol)

q_pickup = sol.q
print(robot.fkine(q_pickup))    # FK shows that desired end-effector pose was achieved
# Out:
# IKsolution(q=array([ 0.21343385,  1.8669104 , -0.22639717,  0.48252627,  0.2197902 ,
#         1.3958973 , -2.03679145]), success=True, reason=None, iterations=12, residual=1.4517502444146319e-11)
#   -1         9.446e-14  2.439e-12  0.7
#    9.449e-14  1         7.257e-13  0.2
#   -2.439e-12  7.257e-13 -1         0.1
#    0         0         0         1

# %%
import roboticstoolbox as rtb
robot = rtb.models.DH.Panda()
print(robot)
qt = rtb.jtraj(robot.qz, q_pickup, 50)
robot.plot(qt.q, movie='panda1.gif')
# Out:
# DHRobot: Panda (by Franka Emika), 7 joints (RRRRRRR), dynamics, geometry, modified DH parameters
# ┏━━━━━━━━┳━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━┓
# ┃ aⱼ₋₁   ┃  ⍺ⱼ₋₁  ┃ θⱼ  ┃  dⱼ   ┃   q⁻    ┃   q⁺   ┃
# ┣━━━━━━━━╋━━━━━━━━╋━━━━━╋━━━━━━━╋━━━━━━━━━╋━━━━━━━━┫
# ┃    0.0 ┃   0.0° ┃  q1 ┃ 0.333 ┃ -166.0° ┃ 166.0° ┃
# ┃    0.0 ┃ -90.0° ┃  q2 ┃   0.0 ┃ -101.0° ┃ 101.0° ┃
# ┃    0.0 ┃  90.0° ┃  q3 ┃ 0.316 ┃ -166.0° ┃ 166.0° ┃
# ┃ 0.0825 ┃  90.0° ┃  q4 ┃   0.0 ┃ -176.0° ┃  -4.0° ┃
# ┃-0.0825 ┃ -90.0° ┃  q5 ┃ 0.384 ┃ -166.0° ┃ 166.0° ┃
# ┃    0.0 ┃  90.0° ┃  q6 ┃   0.0 ┃   -1.0° ┃ 215.0° ┃
# ┃  0.088 ┃  90.0° ┃  q7 ┃ 0.107 ┃ -166.0° ┃ 166.0° ┃
# ┗━━━━━━━━┻━━━━━━━━┻━━━━━┻━━━━━━━┻━━━━━━━━━┻━━━━━━━━┛
#
# ┌─────┬───────────────────────────────────────┐
# │tool │ t = 0, 0, 0.1; rpy/xyz = -45°, 0°, 0° │
# └─────┴───────────────────────────────────────┘
#
# ┌─────┬─────┬────────┬─────┬───────┬─────┬───────┬──────┐
# │name │ q0  │ q1     │ q2  │ q3    │ q4  │ q5    │ q6   │
# ├─────┼─────┼────────┼─────┼───────┼─────┼───────┼──────┤
# │  qz │  0° │  0°    │  0° │  0°   │  0° │  0°   │  0°  │
# │  qr │  0° │ -17.2° │  0° │ -126° │  0° │  115° │  45° │
# └─────┴─────┴────────┴─────┴───────┴─────┴───────┴──────┘
# PyPlot3D backend, t = 2.499999999999999, scene:
#   Panda

# %%
import roboticstoolbox as rtb
p560 = rtb.models.DH.Puma560()
qt = rtb.tools.trajectory.jtraj(p560.qz, p560.qr, 50)
p560.plot(qt.q)
# Out:
# PyPlot3D backend, t = 2.499999999999999, scene:
#   Puma 560

# %%
import numpy as np
