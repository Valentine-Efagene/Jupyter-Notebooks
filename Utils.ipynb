# %% [markdown]
# ### Collect integer array as space separated input

# %%
a = list(map(int, input().rstrip().split()))

# %% [markdown]
# ### Print array

# %%
print('\n'.join(map(str, result)))

# %% [markdown]
# ### Collect string array

# %%
nd = input().split()
